# %%
    import os

# %%
from google.colab import drive

# %%
# !pip install pdfplumber
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.0/49.0 kB 1.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 49.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 80.6 MB/s eta 0:00:00
# ...

# %%
import pdfplumber

# %%
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
pdf = pdfplumber.open('/content/gdrive/MyDrive/x1.pdf')

# %%
pdf.pages
# Out:
# [<Page:1>,
#  <Page:2>,
#  <Page:3>,
#  <Page:4>,
#  <Page:5>,
#  <Page:6>,
#  <Page:7>,
#  <Page:8>,
#  <Page:9>,
#  <Page:10>,
#  <Page:11>,
#  <Page:12>,
#  <Page:13>]

# %%
pdf.metadata
# Out:
# {'ModDate': "D:20240115095520-03'00'",
#  'Creator': 'JasperReports (consolidado)',
#  'CreationDate': "D:20240115095520-03'00'",
#  'Producer': 'iText 2.1.7 by 1T3XT'}

# %%
p1 = pdf.pages[0]

# %%
text = p1.extract_text()
print(text)
# Out:
# Processo: 0000847-87.2019.5.12.0030
# Cálculo: 1436
# PLANILHA DE CÁLCULO
# Reclamante: SEBASTIÃO GILDO DO NASCIMENTO
# Reclamado: SEREDE - SERVIÇOS DE REDE S.A. E OUTRO
# Período do Cálculo: 02/12/2010 a 11/09/2017 Data Ajuizamento: 31/07/2019 Data Liquidação: 31/08/2023
# Resumo do Cálculo
# Descrição do Bruto Devido ao Reclamante Valor Corrigido Juros Total
# 01. INTERVALO INTRAJORNADA 2.923,10 855,07 3.778,17
# 13º SALÁRIO SOBRE 01. INTERVALO INTRAJORNADA 280,00 79,97 359,97
# FÉRIAS + 1/3 SOBRE 01. INTERVALO INTRAJORNADA 328,70 93,49 422,19
# REPOUSO SEMANAL REMUNERADO E FERIADO SOBRE 01. INTERVALO INTRAJORNADA 593,77 173,44 767,21
# 02. INDENIZAÇÃO POR DANOS MORAIS 10.000,00 2.938,04 12.938,04
# FGTS 8% 233,84 75,06 308,90
# MULTA SOBRE FGTS 40% 93,54 27,50 121,04
# Total 14.452,95 4.242,57 18.695,52
# Percentual de Parcelas Remuneratórias e Tributáveis: 28,31%
# Descrição de Créditos e Descontos do Reclamante Valor Descrição de Débitos do Reclamado por Credor Valor
# ...

# %%
tabela = p1.extract_tables()

# %%
tabela
# Out:
# [[['Descrição do Bruto Devido ao Reclamante',
#    'Valor Corrigido',
#    'Juros',
#    'Total'],
#   ['01. INTERVALO INTRAJORNADA', '2.923,10', '855,07', '3.778,17'],
#   ['13º SALÁRIO SOBRE 01. INTERVALO INTRAJORNADA',
#    '280,00',
#    '79,97',
#    '359,97'],
#   ['FÉRIAS + 1/3 SOBRE 01. INTERVALO INTRAJORNADA',
#    '328,70',
#    '93,49',
#    '422,19'],
#   ['REPOUSO SEMANAL REMUNERADO E FERIADO SOBRE 01. INTERVALO INTRAJORNADA',
#    '593,77',
#    '173,44',
#    '767,21'],
#   ['02. INDENIZAÇÃO POR DANOS MORAIS', '10.000,00', '2.938,04', '12.938,04'],
#   ['FGTS 8%', '233,84', '75,06', '308,90'],
#   ['MULTA SOBRE FGTS 40%', '93,54', '27,50', '121,04'],
#   ['Total', '14.452,95', '4.242,57', '18.695,52']],
#  [['Descrição de Créditos e Descontos do Reclamante', 'Valor'],
#   ['VERBAS', '18.265,58'],
#   ['FGTS', '429,94'],
#   ['Bruto Devido ao Reclamante', '18.695,52'],
#   ['DEDUÇÃO DE CONTRIBUIÇÃO SOCIAL', '(361,83)'],
# ...

# %%
import pandas as pd

# %%
df1 = pd.DataFrame(tabela[1:1], columns=tabela[3])
df1.to_csv('segurado3.csv', index=False)
